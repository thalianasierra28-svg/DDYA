# %% [markdown]
# ## Problema - Organización y búsqueda de productos en una tienda
#
# **Instrucción:** completa esta plantilla con tu diseño y desarrollo. Evita incluir soluciones generadas automáticamente.

# %%
nombre_estudiante = "Mariana Shenoa Castiblanco González, Thaliana Rocio Sierra García, Alejandro Gil León, Juan José Mican Rodríguez"
carnet = None

# %% [markdown]
# ## 1) Descripción del problema **[1 pts]**
# Una tienda necesita organizar y consultar los códigos numéricos de sus productos. Estos códigos se registran a medida que llegan los productos, por lo que inicialmente se encuentran desordenados.
# El problema consiste en desarrollar un programa que permita registrar una cantidad determinada de productos, ordenar sus códigos de menor a mayor utilizando el algoritmo Merge Sort y posteriormente buscar un código específico mediante Búsqueda Binaria.

# %% [markdown]
# ## 2) Requerimientos **[2 pts]**
#
# **Requerimientos Funcionales**
# - RF01: El usuario debe registrar una cantidad n de productos en el programa.
# - RF02: El usuario debe poder ingresar un codigo unico para cada producto.
# - RF03: El sistema debe almacenar los codigos en una lista.
# - RF04: El sistema debe organizar los codigos de menor a mayor usando Mergue Sort.
# - RF05: El sitema debe permitir buacar un producto apartir de su codigo unico.
# - RF06: El sitema tiene que hacer la busqueda de algun dato utilizando búsqueda binaria.
# - RF07: El sistema tiene que decir si el codigo ingresado esta asociado a algun producto.
# - RF08: El sitema debe mostrar un mensaje que diga que el codigo no esta regustrado cuando no exista.
#
# **No Funcionales**
# - RNF01: Se debe usar Python como lenguaje de programación.
# - RNF02: El programa debe usar Mergue Sort para ordenar los codigos de los productos.
# - RNF03: El programa debe utilizar la busqueda binaria para encontrar el nombre relacionado con algún producto.
# - RNF04: El programa debe mostrar mensajes claros y entendibles para orientar al usuario.
# - RNF05: El programa debe dejar trabajar con una cantidad variable de productos.
# - RNF06: El programa debe usar las operaciones de ordenamiento y búsqueda de manera eficiente.

# %% [markdown]
# ## 3) Historias de usuario **[2 pts]**
# 1. **El usuario registra los productos:** El encargado de la tienda quiere ingresar la cantidad $n$ de productos y registras sus códigos númericos
#
#     **Criterios de aceptación (CA):**
#
#     1. Primero se solicita la cantidad total de productos a registrar
#     2. Debe permitir el ingreso de cada código númerico uno por uno
#     3. Debe almacenarlos y mostrar la lista original de códigos ingresados
#
# 2. **Ordenamiento (Merge Sort):** El encargado quiere ordenar automáticamente la lista de códigos de productos de menor a mayor usando Merge Sort(Divide y Conquista)
#
#     **Criterios de aceptación (CA):**
#
#     1. El sistema debe procesar la lista desordenada aplicando Merge Sort
#     2. Debe mostrar la lista resultante ordenada correctamente de manera ascendente
#
# 3. **Búsqueda de productos utilizando Búsqueda Binaria:**
#
#     **Criterios de aceptación (CA):**
#
#     1. El sistema requiere la lista previamente ordenada antes de realizar la búsqueda
#     2. Debe solicitar al usuario el código a buscar
#     3. Debe aplicar el algoritmo de búsqueda binaria y decir si el código fue encontrado

# %% [markdown]
# ## 4) Diagramas de flujo **[5 pts]**
#
# ![Semana 3.jpg](attachment:f91ef4c6-f07e-4cb9-bbdc-e6dddf30aade.jpg)

# %% [markdown]
# ## 5) Diagramas de secuencia **[5 pts]**
#
# El diagrama de secuencia muestra el proceso del programa. Primero, el usuario ingresa la cantidad y los códigos de los productos. Luego, Merge Sort ordena los códigos de menor a mayor. Después, el usuario ingresa el código que quiere buscar y Búsqueda Binaria verifica si existe. Finalmente, el sistema muestra si el producto fue encontrado o no.
#
# ![image.png](attachment:d75b735a-b97e-4aa9-beac-827a6351c1f9.png)

# %% [markdown]
# ## 6) Diagramas de casos de uso **[5 pts]**
#
# El diagrama ilustra la interacción entre el Usuario y el Sistema de Organización y Búsqueda, dividido en dos flujos principales: el registro y la búsqueda de productos.
# Al capturar los datos, el sistema valida obligatoriamente que cada ID sea mayor a cero y aplica el algoritmo Merge Sort para ordenar la lista en segundo plano. Posteriormente, cuando el usuario consulta un código, el sistema ejecuta una Búsqueda Binaria sobre la lista ordenada y muestra en pantalla la confirmación de si el producto está registrado o no.
#
# ![image.png](attachment:3c50c554-800e-4c75-84a6-def2c24528fc.png)

# %% [markdown]
# ## 7) Análisis de complejidad **[15 pts]**
# **Merge Sort: Mejor y peor caso O(n log n)**
# ![Gráfica mergesort.jpg](attachment:2fcdb4a8-5468-40ae-9b39-3245b4844ed3.jpg)
# ![Teorema maestro.jpg](attachment:f060d4c4-0ef8-4165-8991-3c584a4ded2b.jpg)
#
# **Gráfica búsqueda binaria mejor caso O(1):**
#
# ![Semana 3 (1).jpg](attachment:d507bb61-bc8d-4b4e-a43e-6dea63d70020.jpg)
#
# **Gráfica búsqueda binaria peor caso O(log n):**
#
# ![Semana 3 (2).jpg](attachment:bf8b7500-d12e-4e27-82d5-93d2d30d85d9.jpg)

# %% [markdown]
# ## 8) Código funcional **[15 pts]**

# %%
# Code
def get_valid_number(prompt):
    while True:
        user_input = input(prompt).strip()
        if user_input.isdigit():
            return int(user_input)
        print("\n\tError: Por favor, ingrese solo dígitos (no letras, espacios ni símbolos).")

def merge(left, right):
    result = []
    i = j = 0

    while i < len(left) and j < len(right):
        if left[i] <= right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1

    result.extend(left[i:])
    result.extend(right[j:])
    return result

def merge_sort(arr):
    if len(arr) <= 1:
        return arr

    mid = len(arr) // 2
    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])

    return merge(left, right)

def binary_search(arr, target):
    low = 0
    high = len(arr) - 1
    while low <= high:
        mid = (low + high) // 2
        if arr[mid] == target:
            return True
        elif arr[mid] < target:
            low = mid + 1
        else:
            high = mid - 1
    return False

def search_menu(code_list):
    while True:
        target_code = get_valid_number("\n\t\tIngrese el código del producto a buscar: ")

        if binary_search(code_list, target_code):
            print(f"\n\t\tEl código {target_code} ESTÁ registrado.")
        else:
            print(f"\n\t\tEl código {target_code} NO ESTÁ registrado.")

        choice = input("\n\t\t¿Buscar otro código? Ingrese (y) para sí o cualquier otra tecla para volver al menú principal: ").strip().lower()
        if choice != "y":
            break

def main_menu():
    code_list = []

    while True:
        print("\n\t\t--ORGANIZACIÓN Y BÚSQUEDA by FairSociety--")
        print("\n\t\t\t--- MENÚ PRINCIPAL ---")
        print("\n\t1. Registrar / Actualizar códigos de productos")
        print("\t2. Buscar un código en la lista almacenada")
        print("\t0. Salir")

        option = input("\n\t\tSeleccione una opción: ").strip()

        if option == "1":
            count = get_valid_number("\n\t\t¿Cuántos códigos desea ingresar?: ")
            new_codes = []
            
            for i in range(count):
                code = get_valid_number(f"\n\tIngrese el código #{i + 1}: ")
                new_codes.append(code)
            
            code_list = merge_sort(new_codes)
            print("\n\tCódigos ordenados:")
            print(code_list)

            while True:
                choice = input("\n\t¿Desea buscar un producto ahora? y = si, n = no (y/n): ").strip().lower()
                if choice == "y":
                    search_menu(code_list)
                    break
                else:
                    print("\n\tError: Por favor, ingrese (y) para sí o (n) para no.")

        elif option == "2":
            if not code_list:
                print("\n\tNo se encontraron códigos en memoria. Por favor, use la opción 1 primero para registrarlos.")
            else:
                search_menu(code_list)

        elif option == "0":
            print("\n\n\tSaliendo del programa...\n")
            break
        else:
            print("Opción inválida. Intente de nuevo.")

if __name__ == "__main__":
    main_menu()
# Out:
# 		--ORGANIZACIÓN Y BÚSQUEDA by FairSociety--
#
# 			--- MENÚ PRINCIPAL ---
#
# 	1. Registrar / Actualizar códigos de productos
# 	2. Buscar un código en la lista almacenada
# 	0. Salir
# 		Seleccione una opción:  1
#
# 		¿Cuántos códigos desea ingresar?:  0
# 	Códigos ordenados:
# []
# 	¿Desea buscar un producto ahora? y = si, n = no (y/n):  h
# 	Error: Por favor, ingrese (y) para sí o (n) para no.
# 	¿Desea buscar un producto ahora? y = si, n = no (y/n):  .
# 	Error: Por favor, ingrese (y) para sí o (n) para no.
